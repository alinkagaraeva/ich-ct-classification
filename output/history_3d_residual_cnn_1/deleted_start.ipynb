# %% [markdown]
# epoch,train_loss,val_loss,train_roc_auc,train_pr_auc,val_roc_auc,val_pr_auc
# 1,0.69132,0.69406,0.49572,0.43303,0.51741,0.4573
# 2,0.69317,0.6965,0.47862,0.41814,0.56593,0.49044
# 3,0.68577,0.68663,0.50952,0.43831,0.56111,0.49795
# 4,0.66386,0.67587,0.61955,0.55354,0.71815,0.6554
# 5,0.61428,0.57422,0.72043,0.6709,0.82593,0.79567
# 6,0.57674,0.51261,0.76327,0.71125,0.82185,0.78514
# 7,0.51628,0.52557,0.82453,0.79073,0.82074,0.74615
