# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Loss every epoch

# %%
df_e = pd.read_csv('epoch_metrics.csv')

plt.figure(figsize=(8, 5))

plt.plot(df_e['epoch'], df_e['train_loss'], marker='o', label='Train')
plt.plot(df_e['epoch'], df_e['val_loss'], marker='o', label='Validation')

plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Train vs Validation Loss')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Roc-auc every epoch

# %%
df_e = pd.read_csv('epoch_metrics.csv')

plt.figure(figsize=(8, 5))

plt.plot(df_e['epoch'], df_e['train_roc_auc'], marker='o', label='Train')
plt.plot(df_e['epoch'], df_e['val_roc_auc'], marker='o', label='Validation')

plt.xlabel('epoch')
plt.ylabel('metric')
plt.title('Train vs Validation roc-auc')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Pr-auc every epoch

# %%
df_e = pd.read_csv('epoch_metrics.csv')

plt.figure(figsize=(8, 5))

plt.plot(df_e['epoch'], df_e['train_pr_auc'], marker='o', label='Train')
plt.plot(df_e['epoch'], df_e['val_pr_auc'], marker='o', label='Validation')

plt.xlabel('epoch')
plt.ylabel('metric')
plt.title('Train vs Validation pr-auc')
plt.legend()
plt.grid(True)

plt.show()
